# %% [markdown]
# # **Notebook\#2: ✨ Design prompts for everyday work tasks** 😎 ✨

# %% [markdown]
# ## **Tackle Your To-Do List with the Help of AI 🚀**
# ### **Exercise: Try It Yourself** ❗
#
# **1. Write down your to-do list for today or this week.**
#
# ### **Answer:**
# 1. Check emails
# 2. Complete fyp project
# 3. Prepare notes for upcoming exam
#
# **2. Pick one task where AI could help.**
# ### **Answer:**
# "Prepare notes for upcoming exam"
#
# **3. Open your AI tool and give it this prompt: "Draft a professional, friendly email reminding my team about our weekly meeting."**
#
# ### **AI Answer:**
#
# Subject: Reminder: Weekly Team Meeting
#
# Hi Team,
#
# Just a friendly reminder about our weekly meeting scheduled for [Day, Date] at [Time]. We’ll be covering [brief agenda points, if applicable], and your participation will be valuable.
#
# Please make sure to join on time so we can make the most of our session. If you have any items to add to the agenda, feel free to send them my way beforehand.
#
# Looking forward to seeing everyone there!
#
# Best regards,
# [Your Name]
#
# ### **Prompt Using One of my Tasks:**
# “Summarize my study material on Cloud Architecture into clear, concise notes with key definitions and examples. Organize them with headings and bullet points so they are easy to revise quickly.”
#
# ### **AI Answer:**
#
# Cloud Architecture Notes
#
# What is Cloud Computing?
#
# * A class of network-based computing that takes place over the Internet.
# * Evolved from Utility Computing.
# * Involves a collection of integrated and networked hardware, software, and Internet infrastructure (platform).
# * Provides hardware, software, and networking services to clients through the Internet.
# * Complexity of infrastructure is hidden from users via:
#     * Simple graphical interfaces
#     * APIs (Application Programming Interfaces)

# %% [markdown]
# ## **Write Emails with Generative AI 📧**
#
# ### **Exercise: Try It Yourself**❗
# Think of an email you need to write (e.g., to your team, customers, or a client).
# Use the prompt framework:
#
# * Persona: Who are you?
# * Context: What’s happening?
# * Task: What do you want the email to do?
# * Specificity: Add tone, format, details.
#
# Ask your AI tool to draft the email.
#
# ### **Answer:**
#
# **Persona**: I am a graduate student working under my supervisors guidance for fyp research paper.
#
# **Context**: I havee made some changes in my research paper and need supervisors review.
#
# **Task**: Ask my supervisor to review the updated version of the paper and provide comments.
#
# **Specificity**: Make it professional, formal, respectful and clear.
#
# #### **AI Tool Answer:**
#
# Subject: Updated Draft of Research Paper for Review
#
# Dear [Supervisor’s Name],
#
# I hope this message finds you well. I have made the requested changes to our research paper and updated several sections based on your earlier feedback. The revised draft is attached for your review.
#
# Could you kindly go through the updated version and let me know if there are any further adjustments required? Your guidance will help me ensure the paper is aligned with our objectives before submission.
#
# Thank you for your time and support.
#
# Best regards,
#
# [Your Full Name]
#
#
# **Specificity**: Make it casual, fun and clear.
#
# #### **AI Tool Answer:**
# Subject: Updated Research Paper – Feedback Welcome
#
# Hi [Supervisor’s Name],
#
# Hope you’re doing well! I’ve made the changes we discussed and updated a few sections of the research paper. The revised draft is attached.
#
# Whenever you get a chance, could you take a look and let me know your thoughts? Any feedback would be super helpful so I can make sure everything’s on track before submission.
#
# Thanks a lot for your time and guidance!
#
# Cheers,
# [Your Name]

# %% [markdown]
# ## **Prompt with Personality: Match Gen AI to Your Writing Style 😎**
#
# ### **Exercise: Try It Yourself**❗
#
# Pick a short text you’ve written (an email, a report, or a social post).
#
# Rewrite your prompt to specify tone and style.
#
# Run it through your AI tool.
#
# Iterate: Ask for a new version in a different tone (funny, formal, academic, casual).
#
# Compare the results — which version feels most effective for your audience?
#
# ### **Answer:**
#
# **Tone: Professional**
#
# Subject: Revised Draft of Research Paper for Your Review
#
# Dear [Supervisor’s Name],
#
# I hope you are doing well. I have incorporated the changes you suggested and updated several sections of the research paper in line with your feedback. Please find the revised draft attached for your review.
#
# I would be grateful if you could review the updated version and advise on any further refinements needed to ensure the paper meets our objectives before submission.
#
# Thank you for your time and continued guidance.
#
# Best regards,
#
# [Your Full Name]
#
# **Tone: Funny and casual**
#
# Subject: Updated Research Paper – Feedback Welcome
#
# Hi [Supervisor’s Name],
#
# Hope you’re doing well! I’ve made the changes we discussed and updated a few sections of the research paper. The revised draft is attached.
#
# Whenever you get a chance, could you take a look and let me know your thoughts? Any feedback would be super helpful so I can make sure everything’s on track before submission.
#
# Thanks a lot for your time and guidance!
#
# Cheers,
# [Your Name]
#
#
# **Professinal seems the most appropriate**

# %% [markdown]
# ## **Brainstorming Ideas with Generative AI**
#
# ###  **Exercises : Try It Yourself ❗**
#
# ### **Exercise 1: Icebreakers**
# Write a prompt asking AI to generate **3 creative icebreakers** for a new teammate who loves basketball and photography.
#
# #### **Answer:**
# I am a team manager, I need to welcome a new member. Generate 3 fun and creative icebreakers for a new teammate who enjoys basketball and photography. Make them lighthearted and good for a casual team introduction.
#
# ### **Exercise 2: Product Launch**
# Imagine you’re launching a **new mobile fitness app** (it can be any product).
# Write a prompt to:
#
# * Define a **6-month launch timeline**.
# * Suggest **3 pre-launch buzz ideas**.
#
# #### **Answer:**
# I am the marketing lead for a new mobile fitness app. Create a 6-month launch timeline and suggest 3 pre-launch buzz ideas, Write them in way that will excite people to sign up for the app. Present the timeline in a table format with bullet points under each month. Keep the tone engaging ans easy-to-read
#
# ### **Exercise 3: Global Audience Twist**
# Take your product launch prompt and **iterate** by asking the AI to adjust the ideas for a **global audience**.
#
# #### **Answer:**
# Adjust the 6 month launch timeline and 3 pre-launch buzz ideas for the fitness app to attract a global audience. Add examples of sifferent  regional elements. Present the timeline in a table format with bullet points under each month.
#
# ### ✅ **Reflection Question** 💡
# How can you use generative AI to **spark new ideas** in your own projects or workplace?
#
# #### **Answer:**
# Generative AI can spark new ideas by giving me  options that I may not think of on my own. It helps me think faster and adjust plans for different audiences. If I give it raw ideas, it can turn them into structured plans I can actually use.

# %% [markdown]
# ## **Build Tables & Trackers Effortlessly with AI**
#
# ### **Exercises: Try It Yourself** ❗
#
# ### **Exercise 1: Project Tracker**
# Prompt AI to create a **project tracker** with columns: Task, Owner, Deadline, Status.
#
# Add constraints: Each owner should have no more than 2 active tasks.
#
# #### **Answer:**
# Create a project tracker table with columns: Task, Owner, Deadline, and Status. Make sure each owner has no more than 2 active tasks at a time.
#
# ### **Exercise 2: Event Schedule**
# You’re planning a **3-day conference**. Ask AI to generate a schedule with:
#
# * Columns: Day, Session Title, Speaker, Time.
# * Constraint: No speaker should have more than 1 session per day.
#
# #### **Answer:**
# Create a 3-day conference schedule in a table with columns: Day, Session Title, Speaker, and Time. Make sure no speaker has more than 1 session per day.
#
# ### **Exercise 3: Team Availability**
# Write a prompt to generate a **vacation tracker** for 8 employees.
#
# * Columns: Employee, Vacation Start, Vacation End.
# * Constraint: At least 5 employees must be available at all times.
#
# #### **Answer:**
# Create a vacation tracker table for 8 employees with columns: Employee, Vacation Start, and Vacation End.  Make sure to apply the rule that at least 5 employees must always be available at all times.
#
# ### ✅ **Reflection Question**
# How could you use AI to **organize recurring tasks** (like meetings, deadlines, or resources) at your workplace?
#
# #### **Answer:**
# AI can help me stay organized by making trackers, schedules, or calendars. For example I can ask it to set up my weekly meetings, list my task deadlines or show when people are available. This makes it easier for me to manage my tasks.

# %% [markdown]
# ## **Capture Meeting Notes Instantly with AI**
#
# ### **Exercises: Try It Yourself** ❗
#
# ***Sample meeting transipt, asked from AI so I can answer questions later on***
#
# Meeting Transcript: Marketing Campaign Planning
#
# Date: September 9, 2025
#
# Attendees:
#
# * Emma (Project Manager)
# * Liam (Marketing Lead)
# * Sofia (Content Writer)
# * Raj (Designer)
# * Maya (Data Analyst)
#
# Emma: Thanks for joining. Let’s get straight into the campaign timeline. Liam, where are we?
#
# Liam: The media plan is drafted. I’ll finalize the ad placements and confirm with vendors by Thursday, September 11.
#
# Sofia: I’ve completed the first draft of the email copy. Social posts are still pending — I’ll finish them and share for review by Friday, September 12.
#
# Raj: Design-wise, the banner concepts are ready. I’ll prepare final versions for both digital and print by Monday, September 15.
#
# Maya: I’ve pulled last quarter’s engagement data. I’ll complete the full performance report and share insights for targeting by Wednesday, September 10.
#
# Emma: Good. Any blockers?
#
# Liam: Only budget approval. Finance still hasn’t cleared it.
#
# Emma: I’ll escalate that today and aim to get confirmation by tomorrow, September 10.
#
# Sofia: Once budget is approved, can we confirm which channels need content priority?
#
# Liam: Yes, I’ll share the priority list alongside vendor confirmations.
#
# Emma: Great. Let’s recap action items:
#
# Liam: Confirm ad placements with vendors – Sep 11; share channel priority list – Sep 11
#
# Sofia: Complete social post drafts – Sep 12
#
# Raj: Deliver final banner designs – Sep 15
#
# Maya: Share performance report – Sep 10
#
# Emma: Secure budget approval – Sep 10
#
# Emma: Next check-in: Tuesday, September 16.
#
# ### **Exercise 1: Speaker-based Minutes**
#
# Take a sample transcript (or your last meeting notes) and prompt AI:
#
# ```
# Summarize the meeting into minutes by speaker.
# Add 2–3 bullet points per speaker, and mark action items clearly.
# ```
#
# ### **Answer:**
#
# Emma (Project Manager)
# * Opened discussion on campaign timeline.
# * Confirmed she will escalate budget approval (Action Item: Budget approval by Sep 10).
# * Scheduled next check-in for Sep 16.
#
# Liam (Marketing Lead)
# * Shared that the media plan is drafted.
# * Action Item: Confirm ad placements with vendors by Sep 11.
# * Action Item: Share channel priority list by Sep 11.
#
# Sofia (Content Writer)
# * Completed draft of email copy.
# * Action Item: Finalize and share social post drafts by Sep 12.
# * Raised question about channel priorities.
#
# Raj (Designer)
# * Reported banner concepts are ready.
# * Action Item: Deliver final versions for digital and print by Sep 15.
#
# Maya (Data Analyst)
# * Shared engagement data from last quarter.
# * Action Item: Complete and deliver full performance report by Sep 10.
#
# ### **Exercise 2: Action-Focused Notes**
#
# Use this prompt:
#
# ```
# Create meeting minutes that focus only on action items.
# Format each entry as: Action Item, Responsible Person, Deadline.
# ```
#
# ### **Answer:**
#
# | Action Item                        | Responsible Person | Deadline     |
# | ---------------------------------- | ------------------ | ------------ |
# | Secure budget approval             | Emma               | Sep 10, 2025 |
# | Confirm ad placements with vendors | Liam               | Sep 11, 2025 |
# | Share channel priority list        | Liam               | Sep 11, 2025 |
# | Complete social post drafts        | Sofia              | Sep 12, 2025 |
# | Deliver final banner designs       | Raj                | Sep 15, 2025 |
# | Share performance report           | Maya               | Sep 10, 2025 |
#
# ### **Exercise 3: Thematic Notes**
#
# Try refining for themes:
#
# ```
# Group meeting minutes into sections based on topics discussed.
# For each section, summarize key decisions, and list assigned action items.
# ```
#
# ### **Answer:**
#
# **Topic: Campaign Timeline & Deliverables**
# * Key decision: All campaign tasks to align with vendor confirmation and budget approval.
# * Action Items:
#   * Liam: Confirm ad placements and share channel priority list (Sep 11).
#   * Sofia: Finalize social posts (Sep 12).
#   * Raj: Deliver final banners (Sep 15).
#
# **Topic: Budget Approval**
# * Blocker identified: Pending finance approval.
# * Key decision: Emma will escalate for confirmation.
# * Action Item: Emma to secure approval (Sep 10).
#
# **Topic: Data & Reporting**
# * Key decision: Targeting to be informed by engagement data.
# * Action Item: Maya to share full performance report (Sep 10).
#
# **Next Steps**
# * Next check-in scheduled: Sep 16.
#
# ### ✅ **Reflection Question** 💡
#
# How could AI-generated meeting notes help you **improve follow-up and accountability** in your workplace?
#
# ### **Answer:**
#
# AI-generated meeting notes can improve follow-up by  making action items, deadlinesand responsibilties clear. It reduces any mismanagemnet later on. People will be accoutable for what and when they have to do.

# %% [markdown]
# ## **Summarize Lengthy Documents with AI**
#
# ### **Exercises: Try It Yourself** ❗
#
# **Sample Article**: [Absolute Success is Luck. Relative Success is Hard Work.](https://jamesclear.com/luck-vs-hard-work)
#
# ### **Exercise 1: Outline Summary**
#
# Take a long article or report. Prompt AI:
#
# ```
# Summarize this document into a bulleted outline of no more than 10 points.
# ```
#
# ### **Answer:**
# * Warren Buffett’s “Ovarian Lottery” shows luck of birth is the biggest factor in absolute success.
# * Luck includes where, when, and into what family you are born.
# * Tu Youyou’s malaria cure story shows persistence and hard work can create breakthroughs.
# * She succeeded despite limited formal credentials and government restrictions.
# * Absolute success = luck. Wild, world-class achievements often depend on rare circumstances.
# * Relative success = hard work. Among people with similar opportunities, effort explains differences.
# * Success is like a graph: luck sets your starting point, hard work sets your slope (trajectory).
# * Time can reduce early advantages or disadvantages, but effort compounds results.
# * Luck opens opportunities, but sustained success depends on hard work.
# * You can increase “luck surface area” by taking action, being prepared, and trying often.
#
# ### **Exercise 2: Audience Summary**
#
# Try this with the same text:
#
# ```
# Summarize this document as if explaining it to a high school student.
# ```
#
# ### **Answer:**
# This article says that both luck and hard work matter in life.
# * Warren Buffett explains that where you’re born is a huge factor in your success—something you can’t control.
# * A scientist named Tu Youyou proved that hard work also matters when she discovered a cure for malaria through persistence and dedication, even though she didn’t have big qualifications.
# * The article says luck usually decides extreme success (like being world-famous), but hard work decides who stands out among people with similar opportunities.
# * Think of it like a graph: luck decides where you start, but hard work decides how steep your progress is.
# * The takeaway: you can’t control your starting point, but you can control your effort, and effort often creates more opportunities for “lucky breaks.”
#
# ### **Exercise 3: Comparative Summary**
#
# Use:
#
# ```
# Summarize this report in two versions:
# 1. Executive summary for leadership.
# 2. Simplified version for frontline employees.
# ```
# ### **Answer:**
#
# **1. Executive Summary for Leadership**
#
# This article highlights the dual role of luck and hard work in achieving success. Warren Buffett’s concept of the “Ovarian Lottery” illustrates how birth circumstances largely shape absolute success. In contrast, Tu Youyou’s malaria breakthrough shows how persistence and discipline drive relative success among peers. The framework suggests:
# * Absolute success is heavily influenced by luck, timing, and uncontrollable factors.
# * Relative success is shaped by choices, habits, and consistent effort.
# * Over time, sustained success requires hard work, even when initial opportunities are shaped by luck.
# * Leaders should recognize the structural advantages at play while fostering environments where disciplined effort is rewarded.
#
# **2. Simplified Version for Frontline Employees**
#
# This article explains that both luck and hard work matter. Some people start life with more advantages, like money or better schools. That’s luck. But among people with similar chances, the ones who work harder and stick with good habits usually do better. You can’t control where you start, but you can control how much effort you put in. Hard work also gives you more chances to get lucky breaks.
#
# ### ✅ **Reflection Question** 💡
# How could tailoring summaries to **different audiences** (executives, clients, students) improve understanding and decision-making in your work?
#
# ### **Answer:**
# If I change the way I write summaries for different people it makes it easier for them to understand. Executives are busy people therefore they need easy to read and short bullet points. Clients demand clear benefits and features so i would highliight that. Students need simple explanations about any topic.

# %% [markdown]
# ## **Practice Advanced Summarization Techniques**
# ### **Exercise**
#
# 1. Take a long article or report.
# 2. Summarize it in 3 steps:
#     - Broad overview (1 paragraph)
#     - Shorter summary (3 bullet points)
#     - Single sentence (main trend/insight).
#
# ### **Answer:**
#
# **Sample Article**: [The Goldilocks Rule: How to Stay Motivated in Life and Business](https://jamesclear.com/goldilocks-rule)
#
# #### **Broad Overview (1 paragraph)**
# The article uses Steve Martin’s journey from a Disney magic shop worker to a world-famous comedian to show how long-term motivation works. His steady growth followed the Goldilocks Rule: people stay most engaged when tasks are not too easy or too hard, but just challenging enough to stretch their abilities. Along with this, progress must be measurable and provide immediate feedback, which fuels both motivation and happiness. Together, these principles explain how habits can be sustained and performance improved over time.
#
# #### **Shorter Summary (3 bullet points)**
# * Goldilocks Rule: Motivation peaks when tasks are at the edge of current abilities—not too hard, not too easy.
# * Feedback & Measurement: Immediate feedback on progress keeps people motivated and creates “flow.”
# * Practical Formula: Choose just-manageable challenges, track results, and repeat for lasting motivation
#
# #### **Single Sentence (main trend/insight)**
# Motivation lasts when you tackle challenges that are just hard enough and measure your progress along the way.
